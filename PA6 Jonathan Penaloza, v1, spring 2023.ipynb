# %% [markdown]
# # PA6 Jonathan Penaloza, v1, spring 2023

# %% [markdown]
# Write a Python program will calculate the area and perimeter of a triangle using two different functions named calcArea() and calcPerimeter().
#
# #Your program should prompt the user for the length of three sides of the triangle.
#
# #Each function should take the lengths of the sides as arguments and return the output of their respective calculations.
#
# #As an added feature, set the default values of your parameters to 1 so if you call either function without parameters, it will still produce output)
#
# #(I recommend using Heron’s Method for calculating the area of a triangle.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt
a = int(input("Enter the side a of the triangle: "))
b = int(input("Enter the side b of the triangle: "))
c = int(input("Enter the side c of the triangle: "))

def calcArea(a=1,b=1,c=1):
    s= (a+b+c)/2

    area = sqrt(s*(s-a)*(s-b)*(s-c))
    return area
def calPerimeter(a=1,b=1, c=1):
    peri = (a+b+c)
    return peri

print(f"The area of the triangle is: {calcArea(a,b,c)}")
print(f"The perimeter of the triangle is: {calPerimeter(a,b,c)}")
# Out:
# Enter the side a of the triangle: 5
# Enter the side b of the triangle: 4
# Enter the side c of the triangle: 3
# The area of the triangle is: 6.0
# The perimeter of the triangle is: 12

# %%
import random

random_number= random.randint(1,1000)
entered_number = None
# print(random_number) To trigger the right number
def evaluateGuess(entered_number):

    while entered_number != random_number:
        entered_number = int(input("Enter a number between 1 and 1000, or enter 0 to scape: "))

        if entered_number == random_number:
            print("You guessed the number correctly, I am quite surprised 🤨")
        elif (entered_number< random_number):
            print("You guessed too low, try again")
        elif (entered_number> random_number):
            print("You guessed too high, try again")
        elif entered_number == 0:
            break

evaluateGuess(entered_number)
# Out:
# 95
# Enter a number between 1 and 1000, or enter 0 to scape: 5
# You guessed too low, try again
# Enter a number between 1 and 1000, or enter 0 to scape: 120
# You guessed too high, try again
# Enter a number between 1 and 1000, or enter 0 to scape: 95
# You guessed the number correctly, I am quite surprised 🤨

# %% [markdown]
# #c.Write a Python program to calculate the mean temperature over a set of Fahrenheit temperature values. Your program should calculate the mean in a function called meanTemp()and then print message that indicates the number of days your mean represents and the mean (see below). Your function should be flexible so that you can pass any number of temperatures to it. You do not need to get input from the user; simply include the temperatures in the function parameter list. Here is a sample run of the program:

# %%
def meanTemp(*args):
    mean = sum(args) / len(args)
    return print(f"The mean temperature over the past {len(args)} days is {round(mean)}")

meanTemp(29,32,34) 
meanTemp(30,32,12,45,32,34)
# Out:
# The mean temperature over the past 3 days is 32
# The mean temperature over the past 6 days is 31
